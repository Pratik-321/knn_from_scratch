# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/My Drive/KNN_DATASET.csv')
ds=dataset.drop('User ID',axis=1)
X = ds.iloc[:, [2, 3]].values
y = ds.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
ds=ds.drop('Gender',axis=1)

# %%
ds
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
columns=list(ds)
columns
# Out:
# ['Age', 'EstimatedSalary', 'Purchased']

# %%
len(ds)
# Out:
# 400

# %%
user=[20,30000]

# %%
data_arr=[]
dist_arr=[]
for i in range(400):
  for j in columns:
    print(ds[j][i])
    elem=ds[j][i]
    data_arr.append(elem)
  print(data_arr)
  dist=((user[0]-data_arr[0])**2 + (user[1]-data_arr[1])**2)**0.5
  dist_arr.append(dist)
  data_arr=[]
# Out:
# 19
# 19000
# 0
# [19, 19000, 0]
# 35
# 20000
# 0
# [35, 20000, 0]
# 26
# 43000
# 0
# [26, 43000, 0]
# 27
# 57000
# 0
# [27, 57000, 0]
# 19
# 76000
# 0
# [19, 76000, 0]
# 27
# 58000
# 0
# [27, 58000, 0]
# 27
# 84000
# 0
# [27, 84000, 0]
# 32
# 150000
# 1
# [32, 150000, 1]
# 25
# 33000
# 0
# [25, 33000, 0]
# 35
# 65000
# 0
# [35, 65000, 0]
# 26
# 80000
# 0
# [26, 80000, 0]
# 26
# 52000
# 0
# [26, 52000, 0]
# 20
# 86000
# 0
# [20, 86000, 0]
# 32
# 18000
# 0
# [32, 18000, 0]
# 18
# 82000
# 0
# [18, 82000, 0]
# 29
# 80000
# 0
# [29, 80000, 0]
# 47
# 25000
# 1
# [47, 25000, 1]
# 45
# 26000
# 1
# [45, 26000, 1]
# 46
# 28000
# 1
# [46, 28000, 1]
# 48
# 29000
# 1
# [48, 29000, 1]
# 45
# 22000
# 1
# [45, 22000, 1]
# 47
# 49000
# 1
# [47, 49000, 1]
# 48
# 41000
# 1
# [48, 41000, 1]
# 45
# 22000
# 1
# [45, 22000, 1]
# 46
# 23000
# 1
# [46, 23000, 1]
# 47
# 20000
# 1
# [47, 20000, 1]
# 49
# 28000
# 1
# [49, 28000, 1]
# 47
# 30000
# 1
# [47, 30000, 1]
# 29
# 43000
# 0
# [29, 43000, 0]
# 31
# ...

# %%
dist_arr
# Out:
# [11000.000045454546,
#  10000.011249993671,
#  13000.00138461531,
#  27000.000907407393,
#  46000.00001086957,
#  28000.000874999987,
#  54000.0004537037,
#  120000.0006,
#  3000.004166663773,
#  35000.00321428556,
#  50000.00036,
#  22000.0008181818,
#  56000.0,
#  12000.0059999985,
#  52000.00003846154,
#  50000.00080999999,
#  5000.072899468567,
#  4000.0781242370754,
#  2000.1689928603532,
#  1000.3919231981034,
#  8000.039062404633,
#  19000.019184200843,
#  11000.03563630591,
#  8000.039062404633,
#  7000.04828554775,
#  10000.03644993357,
#  2000.210238949896,
#  27.0,
#  13000.003115384243,
#  12000.005041665607,
#  44000.00137499998,
#  107000.00022897196,
#  14000.000035714285,
#  14000.0022857141,
#  60000.00040833333,
#  3000.037499765628,
#  2000.0422495537439,
#  19000.002631578765,
#  42000.000428571424,
#  1000.0244996998823,
#  13000.001884615249,
#  21000.00402380914,
#  78000.00144230768,
#  15000.003333332963,
#  54000.00059259259,
#  10000.00044999999,
# ...

# %%
result=ds

# %%
result['Age']=dataset['Age']
result['EstimatedSalary']=dataset['EstimatedSalary']
result['will purchase']=dataset['Purchased']

# %%
result
# Out:
#      Age  EstimatedSalary  Purchased  will purchase
# 0     19            19000          0              0
# 1     35            20000          0              0
# 2     26            43000          0              0
# 3     27            57000          0              0
# 4     19            76000          0              0
# ..   ...              ...        ...            ...
# 395   46            41000          1              1
# 396   51            23000          1              1
# 397   50            20000          1              1
# 398   36            33000          0              0
# 399   49            36000          1              1
#
# [400 rows x 4 columns]

# %%
#for knn we require  k i.e sqrt of total no.entries 
import math
k=math.sqrt(len(result))

# %%
k=int(k)

# %%
count = result['will purchase'].value_counts()[0]
count1 = result['will purchase'].value_counts()[1]

# %%
if(count>count1):
  print("USER WILL NOT PURCHASE BASED ON OUR PREDITIONS")
elif(count1>count):
  print("USER WILL PURCHASE BASED ON OUR PREDICTIONS")
else:
  print("CAN'T DETERMINED")
# Out:
# USER WILL NOT PURCHASE BASED ON OUR PREDITIONS
